# %%
import numpy as np
from math import *
import matplotlib.pyplot as plt
import scipy.linalg as lng

def func(x):
    func = sin(x/5.0) * exp(x/10.0) + 5 * exp(-x/2.0)
    return func

Ox = np.arange(1, 15, 0.1)
Oy = [func(x) for x in Ox]

plt.plot(Ox, Oy)
plt.show()

matrix1 = np.array([[1, 1], [1, 15]])
b1 = np.array([func(1), func(15)])

answer = lng.solve(matrix, b)

print answer

def iterFunc(x):
    return answer[0] + answer[1] * x

plotY1 = [iterFunc(x) for x in Ox]
plt.plot(Ox, plotY1)
plt.show()
# Out:
# [[ 3.43914511]
#  [-0.18692825]]

# %%
matrix2 = np.array([[1, 1, 1], [1, 8, 64], [1, 15, 225]])
b2 = np.array([func(1), func(8), func(15)])

answer2 = lng.solve(matrix2, b2)

print answer2

def iter2Func(x):
    return answer2[0] + answer2[1] * x + answer2[2] * x**2

plotY2 = [iter2Func(x) for x in Ox]
plt.plot(Ox, plotY2)
plt.show()
# Out:
# [ 3.32512949 -0.06531159 -0.00760104]

# %%
matrix3 = np.array([[1, 1, 1, 1],
                   [1, 4, 16, 64],
                   [1, 10, 100, 1000],
                   [1, 15, 225, 3375]])
b3 = np.array([func(1), func(4), func(10), func(15)])

answer3 = lng.solve(matrix3, b3)

print answer3

def iter3Func(x):
    return answer3[0] + answer3[1] * x + answer3[2] * x**2 + answer3[3] * x**3

plotY3 = [iter3Func(x) for x in Ox]
plt.plot(Ox, plotY3)
plt.show()
# Out:
# [ 4.36264154 -1.29552587  0.19333685 -0.00823565]
